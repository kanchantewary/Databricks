# %% [markdown]
# #Add heading that describes the notebook

# %% [markdown]
# ## Description: Provide detailed description here

# %% [markdown]
# ##### Orchestration: Parent notebook or workflow
# ##### Libraries:
# ##### Any reference dataset or configuration file:
# ##### Input Parameters:
# ##### Source Data Objects:
# ##### Target Data Objects:

# %% [markdown]
# Version: 0.1
# Created By: Kanchan K Tewary
# Created Date: 28-04-2022
#
# Version: 0.2
# Updated By: Kanchan K Tewary
# Update Description:

# %%
#Import environment variables from Azure Keyvault

# %%
#Import environment variables from a table in database

# %%
#Import environment variables from a configuration file

# %%
#Define Local variables

# %%
#Define any local functions

# %%
#Read from Azure Blob Storage - Mount
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Read from Azure Blob Storage - JSON

# %%
#Read from Azure Blob Storage - Parquet

# %%
#Read from Azure Blob Storage - csv

# %%
#Read from Azure Blob Storage - XML

# %%
#Read from Azure Blob Storage - Unmount
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Read from Azure SQL DW
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Read from Snowflake
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Read from Cosmos DB
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Read Data from Event Hub
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Specify a schema

# %%
#create a delta table
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Read from a delta table
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Perform necessary calculations
#Best Practice: Check execution plans. If the Spark plan becomes huge or it takes the planning long time, DataFrame.spark.checkpoint() or DataFrame.spark.local_checkpoint()
#Avoid shuffling
#use GroupBy.rank instead of DataFrame.rank, as it is less expensive

# %%
#Apply aggregate functions

# %%
#call REST API
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ### Write data into target

# %%
#Write in a parquet file

# %%
#Write in a csv file

# %%
#Write in a JSON file

# %%
#Write in a Azure SQL DW table

# %%
#Write a Databricks Delta Table

# %% [markdown]
# ### Define Unit Test

# %%
#write unit test assertions

# %%
#Define exception handling logic here
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Define logging. Consider using a common functions

# %%
#Delete any temporary tables after notebook execution
